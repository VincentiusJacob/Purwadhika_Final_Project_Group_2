# %%
# %pip install qdrant-client langchain-openai langchain-qdrant python-dotenv
# Out:
# Requirement already satisfied: qdrant-client in ./final_project/lib/python3.12/site-packages (1.16.1)
# Requirement already satisfied: langchain-openai in ./final_project/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: langchain-qdrant in ./final_project/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: python-dotenv in ./final_project/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: grpcio>=1.41.0 in ./final_project/lib/python3.12/site-packages (from qdrant-client) (1.76.0)
# Requirement already satisfied: httpx>=0.20.0 in ./final_project/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client) (0.28.1)
# Requirement already satisfied: numpy>=1.26 in ./final_project/lib/python3.12/site-packages (from qdrant-client) (2.3.5)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in ./final_project/lib/python3.12/site-packages (from qdrant-client) (3.2.0)
# Requirement already satisfied: protobuf>=3.20.0 in ./final_project/lib/python3.12/site-packages (from qdrant-client) (6.33.2)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8 in ./final_project/lib/python3.12/site-packages (from qdrant-client) (2.12.5)
# Requirement already satisfied: urllib3<3,>=1.26.14 in ./final_project/lib/python3.12/site-packages (from qdrant-client) (2.6.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in ./final_project/lib/python3.12/site-packages (from langchain-openai) (1.1.1)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in ./final_project/lib/python3.12/site-packages (from langchain-openai) (2.9.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in ./final_project/lib/python3.12/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./final_project/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./final_project/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.4.56)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in ./final_project/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./final_project/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./final_project/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./final_project/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./final_project/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./final_project/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in ./final_project/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./final_project/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in ./final_project/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in ./final_project/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (0.25.0)
# Requirement already satisfied: anyio in ./final_project/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (4.12.0)
# Requirement already satisfied: certifi in ./final_project/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in ./final_project/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.0.9)
# Requirement already satisfied: idna in ./final_project/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (3.11)
# Requirement already satisfied: h11>=0.16 in ./final_project/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./final_project/lib/python3.12/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in ./final_project/lib/python3.12/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in ./final_project/lib/python3.12/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./final_project/lib/python3.12/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./final_project/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./final_project/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./final_project/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant-client) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in ./final_project/lib/python3.12/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: h2<5,>=3 in ./final_project/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in ./final_project/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in ./final_project/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (4.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./final_project/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-openai) (3.4.4)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import getpass
import os
import hashlib

from uuid import uuid4

from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from qdrant_client import QdrantClient
from langchain_qdrant import QdrantVectorStore
from qdrant_client.http.models import Distance, VectorParams
from dotenv import load_dotenv

# %%
load_dotenv()

if os.getenv("OPENAI_API_KEY"):
    OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
else:
    OPENAI_API_KEY = getpass.getpass("Enter key for OpenAI key: ")

if os.getenv("QDRANT_API_KEY"):
    QDRANT_API_KEY = os.getenv("QDRANT_API_KEY")
else:
    QDRANT_API_KEY = getpass.getpass("QDRANT_API_KEY")

if os.getenv("QDRANT_ENDPOINT"):
    QDRANT_ENDPOINT = os.getenv("QDRANT_ENDPOINT")
else:
    QDRANT_ENDPOINT = getpass.getpass("QDRANT_ENDPOINT")

# %%
qdrant_client = QdrantClient(
    api_key=QDRANT_API_KEY,
    url=QDRANT_ENDPOINT
)

embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.3
)

# %% [markdown]
# ## Retrieve Data

# %%
INPUT_FILE = "./data/jobs.jsonl"

df = pd.read_json(INPUT_FILE, lines=True)
df.head()
# Out:
#                  job_title                      company_name  \
# 0             Data Analyst  PT Matahari Department Store Tbk
# 1      Data Analyst Intern   PT Surya Semesta Internusa, Tbk
# 2  Data Analyst Supervisor                 PT Pangan Lestari
# 3             Data Analyst                     PT 8 ELEMENTS
# 4             Data Analyst             PT Quadra Inti Solusi
#
#                         location    work_type salary  \
# 0               Karawaci, Banten    Full time   None
# 1  Jakarta Selatan, Jakarta Raya  Paruh waktu   None
# 2           Surabaya, Jawa Timur    Full time   None
# 3    Jakarta Barat, Jakarta Raya    Full time   None
# 4              Bogor, Jawa Barat    Full time   None
#
#                                      job_description  \
# 0  Responsibilities:\nCollect, manage, and analyz...
# 1  Job Description\nSupport in conducting thoroug...
# 2  Tugas dan Tanggung Jawab:\nMembuat dan mengemb...
# 3  Job Description\nData Analysis and Interpretat...
# 4  Kualifikasi:\nPendidikan minimal S1 Statistik,...
#
#             _scrape_timestamp
# 0  2025-11-24T11:33:16.277561
# 1  2025-11-24T11:33:32.629908
# 2  2025-11-24T11:33:48.982129
# 3  2025-11-24T11:34:05.465459
# 4  2025-11-24T11:34:22.379464

# %%
documents = []

for index, row in df.iterrows():

    job_title = str(row.get('job_title', ''))
    company_name = str(row.get('company_name', ''))
    job_location = str(row.get('location', '')).replace('\n', ' ')
    job_salary = str(row.get('salary', '')) if row.get('salary') != "None" else "Tidak Ditampilkan"
    job_type = str(row.get('work_type', ''))

    raw_desc = str(row.get('job_description', ''))
    clean_desc = " ".join(raw_desc.split())

    page_content_template = f"""
        Job: {job_title}
        Company: {company_name}
        Location: {job_location}
        Salary: {job_salary}
        Work Type: {job_type}
        Job Description: {clean_desc}
    """.strip()

    metadata_template = {
        "job_title": job_title,
        "company_name": company_name,
        "location": job_location,
        "salary": job_salary,
        "work_type": job_type,
    }
    
    unique_identifier = f"{job_title}_{company_name}_{job_location}".lower().encode('utf-8')
    doc_id = hashlib.md5(unique_identifier).hexdigest()

    doc = Document(
        page_content=page_content_template,
        metadata=metadata_template,
        id=doc_id
    )

    documents.append(doc)


print(f"Total Dokumen: {len(documents)}")
print("\nContoh Dokumen Pertama:")
print(documents[0].page_content)
print("\nMetadata:")
print(documents[0].metadata)
print("\nID:")
print(documents[0].id)
# Out:
# Total Dokumen: 473
#
# Contoh Dokumen Pertama:
# Job: Data Analyst
#         Company: PT Matahari Department Store Tbk
#         Location: Karawaci, Banten
#         Salary: Tidak Ditampilkan
#         Work Type: Full time
#         Job Description: Responsibilities: Collect, manage, and analyze large datasets related to store performance and operational efficiency. Support ongoing business and improvement projects by providing data insights, reports, and dashboards. Collaborate with cross-functional teams (Operations, Merchandising, and Finance) to ensure accuracy and consistency of business data. Assist in identifying trends, issues, and opportunities based on data analysis to support decision-making. Develop and improve data tracking systems or templates to increase reporting efficiency. Requirements : Bachelor’s degree in Business, Statistics, Industrial Engineering, or a related field. 1–2 years of experience in data analysis, business operations, or project support. Strong analytical and numerical skills with attention to detail. Proficient in Microsoft Excel and familiar with data visualization tools. Comfortable handling large datasets and transforming them into actionable insights.
#
# Metadata:
# {'job_title': 'Data Analyst', 'company_name': 'PT Matahari Department Store Tbk', 'location': 'Karawaci, Banten', 'salary': 'Tidak Ditampilkan', 'work_type': 'Full time'}
#
# ID:
# 2876b68aef88cfa9825f3f546cd30b2e

# %% [markdown]
# ## Store Documents to Qdrant

# %%
qdrant = QdrantVectorStore.from_documents(
    documents,
    embedding_model,
    url=QDRANT_ENDPOINT,
    prefer_grpc=True,
    api_key=QDRANT_API_KEY,
    collection_name="Jobs_Documents"
)   

collection_response = qdrant_client.get_collections()
print(f"Collections: {collection_response.collections}")
# Out:
# Collections: [CollectionDescription(name='autoness-collection'), CollectionDescription(name='Jobs_Documents'), CollectionDescription(name='capstone')]

# %%
qdrant_query = QdrantVectorStore.from_existing_collection(
    "Jobs_Documents",
    embedding_model,
    url=QDRANT_ENDPOINT,
    api_key=QDRANT_API_KEY
)

# %%
results = qdrant_query.similarity_search_with_score(
    "Pekerjaan Remote di Jakarta",
    k=3
)

results
# Out:
# [(Document(metadata={'work_type': 'Full time', 'salary': 'Tidak Ditampilkan', 'company_name': 'Savant Degrees Pte Ltd', 'job_title': 'Senior Software Developer', 'location': 'Jakarta Raya (Hibrid)', '_id': '8820eb8c-7cbc-fa24-8aba-64e7974c7bdb', '_collection_name': 'Jobs_Documents'}, page_content='Job: Senior Software Developer\n        Company: Savant Degrees Pte Ltd\n        Location: Jakarta Raya (Hibrid)\n        Salary: Tidak Ditampilkan\n        Work Type: Full time\n        Job Description: We’re looking for a passionate and technically talented individual to join us as a software developer in Indonesia. You will be working in an hybrid-remote working environment. The ideal candidate focuses on building great products with delightful user experiences. You’ll be expected to be super organized, proactive and have a strong point of view on how digital products should be made. Skills & Experience Needed Minimum 8 - 10 years of current, hands-on experience in software development Bachelors or Masters degree in Computer Science, Information Systems, or equivalent Strong Java, HTML, CSS, JavaScript skills, with knowledge on Groovy, Apache Tomcat, Python, and JSON an added advantage Proficient verbal and written English communication skills due to project requirement Experience with at least one modern programming language with an MVC framework Possess a balance of theoretical knowledge and practical exposure Resourceful and tenacious in solving problems Proactive and able to exercise initiative Responsibilities include: Database design and development Coding (e.g. experience in Java, HTML, CSS, JavaScript) Assessing IT security protocols are followed using tools for performance/load testing, and vulnerability scanning Assisting in implementing tools into existing project systems such as Kibana, Katalon, and Logrocket Supporting engineering team to develop software solutions, from software task creation, to technical documentation, and QA testing Participate in User Acceptance Testing (UAT) and help our development team with code development for bugs identified (depending on the software, could be Groovy/Stripes for applications; or HTML5/Javascript for front-end) Mentoring and build the basic foundation skills of junior developers in the team'),
#   0.57984126),
#  (Document(metadata={'work_type': 'Full time', 'location': 'Jakarta Raya', 'salary': 'Tidak Ditampilkan', 'company_name': 'PT. PUSAT BANDAR BERDIKARI', 'job_title': 'STAFF PERSONALIA', '_id': 'ff91ecd2-765e-b325-6b25-d463e6f1f9a5', '_collection_name': 'Jobs_Documents'}, page_content='Job: STAFF PERSONALIA\n        Company: PT. PUSAT BANDAR BERDIKARI\n        Location: Jakarta Raya\n        Salary: Tidak Ditampilkan\n        Work Type: Full time\n        Job Description: Bandar Jakarta Group , membutuhkan tenaga kerja yang profesional dan dinamis untuk bergabung bersama kami sebagai : “ STAFF PERSONALIA “ Deskripsi Pekerjaan : Bertanggung jawab atas laporan absensi karyawan Membantu penyediaan tenaga kerja yang diperlukan untuk divisi terkait Memastikan semua pertanyaan dan kritikan tamu melalui sosial media sudah terjawab dengan baik Memastikan semua pencatatan kehadiran karyawan dilakukan dengan baik dan benar Memastikan pembuatan surat surat yang diperlukan yang berhubungan dengan ketenaga kerjaan Memastikan ketersediaan semua kebutuhan penunjang karyawan (seragam, obat obatan, kartu nama dll) Melakukan komunikasi dan menjalin kedekatan dengan setiap karyawan Bertanggung Jawab Kepada : Manager HRD & Manager Outlet Kualifikasi: Pendidikan min D3 segala jurusan Mampu berkomunikasi dengan sangat baik Pengalaman di posisi yang sama minimal 1 tahun Jujur, teliti, rapi dan aktif Mampu mengoperasikan Microsoft Office ( Word & Excel ) Diutamakan yang memiliki kendaraan pribadi Bersedia ditempatkan di Pantai Indah Kapuk 2 ( PIK 2 ) Bagi yang memenuhi syarat di atas, dapat mengirimkan Surat Lamaran Lengkap ke : hrd@bandar-djakarta.com'),
#   0.57917744),
#  (Document(metadata={'location': 'Jakarta Selatan, Jakarta Raya (Hibrid)', 'work_type': 'Full time', 'salary': 'Rp\xa06.750.000 – Rp\xa09.500.000 per month', 'company_name': 'Pengiklan Anonim', 'job_title': 'Data Analyst', '_id': '7d459b5e-8f44-3882-0990-3ffb55167bd2', '_collection_name': 'Jobs_Documents'}, page_content='Job: Data Analyst\n        Company: Pengiklan Anonim\n        Location: Jakarta Selatan, Jakarta Raya (Hibrid)\n        Salary: Rp\xa06.750.000 – Rp\xa09.500.000 per month\n        Work Type: Full time\n        Job Description: Job Description – Data Analyst (Hybrid) Location: Jakarta (Hybrid) Ringkasan Peran Data Analyst bertanggung jawab untuk mengumpulkan, mengolah, dan menganalisis data kompetitor untuk menghasilkan insight yang mendukung pengambilan keputusan strategis. Hasil analisis akan disampaikan secara teratur dalam bentuk laporan mingguan kepada tim internal. Tanggung Jawab Utama Melakukan riset berkala terhadap kompetitor (layanan, harga, positioning, aktivitas pemasaran, dsb.). Mengumpulkan data dari berbagai sumber (website, publikasi, laporan industri, media sosial, dll). Menganalisis data untuk mengidentifikasi tren pasar, perubahan strategi, serta peluang atau risiko. Menyusun laporan mingguan yang ringkas, sistematis, dan mudah dipahami. Membuat visualisasi data (grafik, tabel, dashboard) agar insight dapat dipahami dengan cepat. Berkolaborasi dengan tim lintas divisi (misalnya marketing, business development, dan manajemen). Memberikan rekomendasi berbasis data untuk mendukung strategi perusahaan. Menjaga akurasi data dan konsistensi metode analisis. Mendukung pengembangan tools internal untuk membantu proses pemantauan kompetitor. Kualifikasi Pendidikan minimal S1 di bidang Statistik, Ekonomi, Data Science, Business Intelligence, atau terkait. Pengalaman minimal 1–2 tahun sebagai Data Analyst (fresh graduate dipersilakan melamar). Terbiasa bekerja dengan data dalam jumlah besar dan menghasilkan insight yang bernilai. Menguasai tools analitik seperti Excel/Google Sheets, Power BI, Tableau, atau sejenisnya. Memiliki kemampuan riset yang kuat dan perhatian tinggi terhadap detail. Mampu membuat laporan yang jelas, terstruktur, dan mudah dipahami. Mampu bekerja secara mandiri maupun kolaboratif. Proaktif, analitis, dan berorientasi pada hasil. Pengetahuan mengenai riset kompetitif menjadi nilai tambah. Sistem Kerja Hybrid – kombinasi kerja remote dan onsite (Jakarta). Deliverables Utama Laporan analisis kompetitor mingguan. Rekomendasi strategis. Dashboard sederhana untuk pemantauan kompetitor (opsional). Soft Skills Critical thinking Manajemen waktu yang baik Detail oriented Adaptable Komunikatif & kolaboratif'),
#   0.5720823)]
